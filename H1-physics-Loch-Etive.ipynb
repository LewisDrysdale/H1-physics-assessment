# %%
import pandas as pd
import numpy as np
import gsw
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('RE2 Etive 22-10-20 CTD file.xlsx', sheet_name=0) # can also index sheet by name or fetch all sheets
df
# Out:
#     DepSM   PrdM   Tv290C    Sal00  Sigma-t00    C0mS/cm  Sbeox0Mg/L  \
# 0     1.0  1.009  11.0115   9.0734     6.6614  11.368316      5.4072
# 1     2.0  2.018  11.2857  11.7914     8.7294  14.578576      5.0711
# 2     3.0  3.028  12.1183  17.2269    12.8102  21.093866      4.7350
# 3     4.0  4.037  12.5052  18.6519    13.8486  22.897526      4.4784
# 4     5.0  5.046  13.0198  20.4252    15.1295  25.187426      4.1966
# ..    ...    ...      ...      ...        ...        ...         ...
# 82    NaN    NaN      NaN      NaN        NaN        NaN         NaN
# 83    NaN    NaN      NaN      NaN        NaN        NaN         NaN
# 84    NaN    NaN      NaN      NaN        NaN        NaN         NaN
# 85    NaN    NaN      NaN      NaN        NaN        NaN         NaN
# 86    1.0  1.009  11.3727  10.8283     7.9737  13.510585      5.5493
#
#     Sbeox0Mm/L  FlECO-AFL
# 0      168.979     1.5102
# 1      158.473     1.5251
# 2      147.971     1.5334
# 3      139.952     1.3793
# ...

# %%
x=df.Sal00;
y=df.DepSM;

fig, ax = plt.subplots()
ax.plot(x, y)
